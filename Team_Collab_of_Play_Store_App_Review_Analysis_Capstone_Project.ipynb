# %% [markdown]
# <a href="https://colab.research.google.com/github/vivek26kumar/play-store-data-analysis/blob/main/Team_Collab_of_Play_Store_App_Review_Analysis_Capstone_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## <b> The Play Store apps data has enormous potential to drive app-making businesses to success. Actionable insights can be drawn for developers to work on and capture the Android market. </b>
#
# ## <b> Each app (row) has values for catergory, rating, size, and more. Another dataset contains customer reviews of the android apps.</b>
#
# ## <b> Explore and analyze the data to discover key factors responsible for app engagement and success. </b>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import seaborn as snb
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/drive/MyDrive/almabetter/Play Store Data.csv')

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df.head(10)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                         Paper flowers instructions  ART_AND_DESIGN     4.4
# 6            Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                   Infinite Painter  ART_AND_DESIGN     4.1
# 8                               Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                      Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# ...

# %%
df.tail()
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# ...

# %%
df.tail(10)
# Out:
#                                                  App             Category  \
# 10831                       payermonstationnement.fr  MAPS_AND_NAVIGATION
# 10832                                       FR Tides              WEATHER
# 10833                                    Chemin (fr)  BOOKS_AND_REFERENCE
# 10834                                  FR Calculator               FAMILY
# 10835                                       FR Forms             BUSINESS
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10831     NaN      38                9.8M       5,000+  Free     0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f7953245d90>]],
#       dtype=object)

# %%
df.count()
# Out:
# App               10841
# Category          10841
# Rating             9367
# Reviews           10841
# Size              10841
# Installs          10841
# Type              10840
# Price             10841
# Content Rating    10840
# Genres            10841
# Last Updated      10841
# Current Ver       10833
# Android Ver       10838
# dtype: int64

# %% [markdown]
# **Calculating total number of rows and column in the data frame**

# %%
df.shape
# Out:
# (10841, 13)

# %% [markdown]
# **Calculating number of null values in each column**

# %%
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
df.boxplot()

# %% [markdown]
# **We found that there is one outlier present in the box plot**

# %% [markdown]
# **Checking in which row number Rating is more than 5,because rating more than 5 is not practically possible**

# %%
df[df.Rating>5]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %% [markdown]
# **Dropping this row '10472':**

# %%
df.drop([10472],inplace=True)

# %% [markdown]
# **Checking whether the dropped row is present or not:**

# %%
df[10470:10475]
# Out:
#                            App         Category  Rating Reviews  Size  \
# 10470               Jazz Wi-Fi    COMMUNICATION     3.4      49  4.0M
# 10471         Xposed Wi-Fi-Pwd  PERSONALIZATION     3.5    1042  404k
# 10473  osmino Wi-Fi: free WiFi            TOOLS     4.2  134203  4.1M
# 10474             Sat-Fi Voice    COMMUNICATION     3.4      37   14M
# 10475         Wi-Fi Visualizer            TOOLS     3.9     132  2.6M
#
#           Installs  Type Price Content Rating           Genres  \
# 10470      10,000+  Free     0       Everyone    Communication
# 10471     100,000+  Free     0       Everyone  Personalization
# 10473  10,000,000+  Free     0       Everyone            Tools
# 10474       1,000+  Free     0       Everyone    Communication
# 10475      50,000+  Free     0       Everyone            Tools
#
#             Last Updated Current Ver   Android Ver
# 10470  February 10, 2017         0.1    2.3 and up
# 10471     August 5, 2014       3.0.0  4.0.3 and up
# ...

# %% [markdown]
# **Checking the boxplot after the Rating column is dropped**

# %%
df.boxplot('Rating')

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# **As there are 1474 null values in the rating column so we have to replace these null values with their median**

# %%
def replace_median(column):
  return column.fillna(column.median)

# %%
df.Rating = df ['Rating'].transform(replace_median)

# %%
df.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              1
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       8
# Android Ver       2
# dtype: int64

# %%
df.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              1
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       8
# Android Ver       2
# dtype: int64

# %%
print(df['Type'].mode())
print(df['Current Ver'].mode())
print(df['Android Ver'].mode())
# Out:
# 0    Free
# dtype: object
# 0    Varies with device
# dtype: object
# 0    4.1 and up
# dtype: object

# %%
df['Type'].fillna(str(df['Type'].mode().values[0]),inplace=True)
df['Current Ver'].fillna(str(df['Current Ver'].mode().values[0]),inplace=True)
df['Android Ver'].fillna(str(df['Android Ver'].mode().values[0]),inplace=True)
df['Android Ver'].fillna(str(df['Android Ver'].mode().values[0]),inplace=True)
df['Content Rating'].fillna(str(df['Content Rating'].mode().values[0]),inplace=True)

# %%
df.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %%
df['Price']=df['Price'].apply((lambda x: str(x).replace('$','') if '$' in str(x) else str(x)))#to make the data frame look nice
df['Reviews']=pd.to_numeric(df['Reviews'],errors='coerce')#to convert all the reviews into numerical value 
df['Price']=pd.to_numeric(df['Price'],errors='coerce')#to convert all the prices into numerical value

# %%
df['Installs']=df['Installs'].apply(lambda x: str(x).replace('+','')if '+' in str(x) else str(x))#to make the data frame look nice
df['Installs']=df['Installs'].apply(lambda x: str(x).replace(',','')if ',' in str(x) else str(x))#to make the data frame look nice
df['Installs']=pd.to_numeric(df['Installs'],errors='coerce')#to convert the Install column into numerical value

# %%
df.head(5)
# Out:
#                                                  App        Category Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN    4.1
# 1                                Coloring book moana  ART_AND_DESIGN    3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN    4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN    4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN    4.3
#
#    Reviews  Size  Installs  Type  Price Content Rating  \
# 0      159   19M     10000  Free    0.0       Everyone
# 1      967   14M    500000  Free    0.0       Everyone
# 2    87510  8.7M   5000000  Free    0.0       Everyone
# 3   215644   25M  50000000  Free    0.0           Teen
# 4      967  2.8M    100000  Free    0.0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df.describe()
# Out:
#             Reviews      Installs         Price
# count  1.084000e+04  1.084000e+04  10840.000000
# mean   4.441529e+05  1.546434e+07      1.027368
# std    2.927761e+06  8.502936e+07     15.949703
# min    0.000000e+00  0.000000e+00      0.000000
# 25%    3.800000e+01  1.000000e+03      0.000000
# 50%    2.094000e+03  1.000000e+05      0.000000
# 75%    5.477550e+04  5.000000e+06      0.000000
# max    7.815831e+07  1.000000e+09    400.000000

# %% [markdown]
# **Data Visualization**

# %%
 grp= df.groupby('Category')
 x=grp['Installs'].agg(np.mean)
 y=grp['Price'].agg(np.sum)
 z=grp['Reviews'].agg(np.mean)
 print(x)
 print(y)
 print(z)
# Out:
# Category
# ART_AND_DESIGN         1.912894e+06
# AUTO_AND_VEHICLES      6.250613e+05
# BEAUTY                 5.131519e+05
# BOOKS_AND_REFERENCE    8.318050e+06
# BUSINESS               2.178076e+06
# COMICS                 9.347692e+05
# COMMUNICATION          8.435989e+07
# DATING                 1.129533e+06
# EDUCATION              5.586231e+06
# ENTERTAINMENT          1.925611e+07
# EVENTS                 2.495806e+05
# FAMILY                 5.201959e+06
# FINANCE                2.395215e+06
# FOOD_AND_DRINK         2.156683e+06
# GAME                   3.066960e+07
# HEALTH_AND_FITNESS     4.642441e+06
# HOUSE_AND_HOME         1.917187e+06
# LIBRARIES_AND_DEMO     7.411284e+05
# LIFESTYLE              1.407444e+06
# MAPS_AND_NAVIGATION    5.286729e+06
# MEDICAL                1.150269e+05
# NEWS_AND_MAGAZINES     2.648876e+07
# PARENTING              5.253518e+05
# PERSONALIZATION        5.932385e+06
# PHOTOGRAPHY            3.011417e+07
# PRODUCTIVITY           3.343418e+07
# ...

# %%
plt.figure(figsize=(16,5))
plt.plot(x,'ro',color='blue')
plt.xticks(rotation=90)
plt.title('Category vs Installs')
plt.xlabel('Categories------------>')
plt.ylabel('Installs------------->')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.figure(figsize=(16,5))
plt.plot(y,'r--',color='red')
plt.xticks(rotation=90)
plt.title('Category vs Pricing')
plt.xlabel('Categories------------>')
plt.ylabel('Prices------------>')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.figure(figsize=(16,5))
plt.plot(z,'g^',color='green')
plt.xticks(rotation=90)
plt.title('Category vs Reviews')
plt.xlabel('Categories------------>')
plt.ylabel('Reviews------------>')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# **Finding the application which have the maximum number of reviews**

# %%
df['Reviews'].max()
# Out:
# 78158306

# %% [markdown]
# **To find the app with maximum number of reviews**

# %%
df[df.Reviews==78158306]
# Out:
#            App Category Rating   Reviews                Size    Installs  \
# 2544  Facebook   SOCIAL    4.1  78158306  Varies with device  1000000000
#
#       Type  Price Content Rating  Genres    Last Updated         Current Ver  \
# 2544  Free    0.0           Teen  Social  August 3, 2018  Varies with device
#
#              Android Ver
# 2544  Varies with device

# %% [markdown]
# **To find apps with maximum number of installs**

# %%
df['Installs'].max()
# Out:
# 1000000000

# %%
df["Price"].max()
# Out:
# 400.0

# %% [markdown]
# **To  find the most costliest app in the playstore**

# %%
df[df.Price==400]
# Out:
#                            App   Category Rating  Reviews  Size  Installs  \
# 4367  I'm Rich - Trump Edition  LIFESTYLE    3.6      275  7.3M     10000
#
#       Type  Price Content Rating     Genres Last Updated Current Ver  \
# 4367  Paid  400.0       Everyone  Lifestyle  May 3, 2018       1.0.1
#
#      Android Ver
# 4367  4.1 and up

# %% [markdown]
# **Finding the application with lowest size**

# %%
df['Size'].min()
# Out:
# '1.0M'

# %% [markdown]
# **Finding the applications which have lowest rating:**

# %%
df[df.Rating==1]
# Out:
#                                                     App       Category Rating  \
# 625                             House party - live chat         DATING    1.0
# 4127                                  Speech Therapy: F         FAMILY    1.0
# 5151                                      Clarksburg AH        MEDICAL    1.0
# 5978                      Truck Driving Test Class 3 BC         FAMILY    1.0
# 6319                   BJ Bridge Standard American 2018           GAME    1.0
# 6490                                             MbH BM        MEDICAL    1.0
# 7144                                      CB Mobile Biz        FINANCE    1.0
# 7383                                     Thistletown CI   PRODUCTIVITY    1.0
# 7427                                     CJ DVD Rentals  COMMUNICATION    1.0
# 7806                                        CR Magazine       BUSINESS    1.0
# 7926                               Tech CU Card Manager        FINANCE    1.0
# ...

# %% [markdown]
# # Summary

# %% [markdown]
# We(**Ankur,Saniya,Vivek,Pravin,Ratnesh**) are a five membered group and we have worked on play store app review analysis capstone project.First we mounted our drive with the collab notebook where I am going to write my code.Then we imported the playstore csv file into the collab notebook.then we imported all the libraries which are required for my data analsis,data cleaning and data visualisation process ,the libraries includes numpy,pandas,matplotlib.pyplot and sea born.Then we read my the csv file with the help of pandas library and stored in a object named **df** which will act as the data frame for the complete Project.

# %% [markdown]
# **Data_Analysis** :  After this we found out the first five rows and last five rows with  the help of **head()** and **tail()** functions respectively.Then with the help of **info** function we get to know that there are lots of null values in many of the columns in the data frame where we are working currently.Then we also find out the mean ,count and standard deviation of the rating column.We used **isnull** function to exactly know that which column has how many null values,and we found out that the rating column has maximum number of null values(1474) present.After that we used **hist** and **boxplot** functions to print the histogram and boxplot for the rating parameter and the result was very surprising.We found out that there is an outlier in the rating coloumn(that is there is a row in which some guy has given a rating of 19.0 which is practically impossible because rating cannot exceed more than 5).So removal of it was necessary and we left it for data cleaning process

# %% [markdown]
# **Data_Cleaning**: We decided to drop that row in which the outlier was coming in the rating column so that my boxplot and histogram becomes perfect.We found out the row number which was 10472 and we dropped that row by using drop function.We checked again to make sure that the row was not present.Then we decided to replace all the null values so that my data frame looks nice and meaningful ,as the rating column had the maximum null values so we started from there only. We declare a function and passed a variable there,and there we wrote the code to replace all the null values with the median of all the values of a particular column(which contains numeric data type values) in a data frame.
# we passed the rating column in that functon as the variable.We checked and finally found that there were no null values in the rating column.we also replaced the null values for the columns which have characteristic values with their mode.Then we found the price column and the Install column was not looking very nice,so we used lambda function to replace the '+' sign with 'space' and ',' with 'space'

# %% [markdown]
# **Data_Visualisation**: We used groupby method to group the Category column and made the object for price,installs and review column as their respective sum,mean and mean values.we did this to plot the graphs.We plotted graphs("Category vs Installs","Category vs Pricing" and "Category vs Reviews") with the help of matplotlib.pyplot library.This is how we completed our whole capstone project.

# %% [markdown]
# #Conclusion

# %% [markdown]
# 1)After checking the **Rating** column filled with lots of null values, we decided to replace them with their median values

# %% [markdown]
# 2)We also found null values in **current_ver** and **android_ver** column and we repaced them with the mode of the those respective columns

# %% [markdown]
# 3)We found an outlier in the **Rating** column after checking through the box plot,and removed it using the drop function ,we passed the row number where the outlier was present in the drop function and that row was removed from the data frame

# %% [markdown]
# 4)We Plotted the histogram

# %% [markdown]
# 5)We used the lambda function to replace the unnecessary symbols like '+'
# from certain column of the data frame so that my data frame looks nice and clean

# %% [markdown]
# 6)We grouped the Category column by groupby function so that I can categorize the other columns with the category column and made the object for them to find mean and sum,it was needed to plot the graphs

# %% [markdown]
# 7)We plotted "Category vs Price" graph plot using matplotlib library

# %% [markdown]
# 8)We plotted "Category vs Reviews" graph plot using matplotlib library

# %% [markdown]
# 9)We plotted "Category vs Install" graph plot using matplotlib library
